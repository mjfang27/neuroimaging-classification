# %%
"""
first step in forward modeling analysis - getting the data from NeuroVault,
    labeled with cognitive concepts from the Cognitive Atlas

"""

from cognitiveatlas.api import get_task, get_concept

from pybraincompare.compare.maths import TtoZ
from pybraincompare.mr.datasets import get_standard_brain
from nilearn.image import resample_img
from pyneurovault import api

from glob import glob
from utils import (
   get_base, get_pwd, make_dirs
)

import nibabel
import numpy
import os
import pandas
import shutil
import sys

if sys.version_info < (3, 0):
    from exceptions import ValueError

# Get the base and present working directory
base = get_base()
here = get_pwd()

data_directory = os.path.abspath("%s/data" %(here))
results_directory = os.path.abspath("%s/results" %(here))

folders = [data_directory,results_directory]
make_dirs(folders)

# Get all collections
collections = api.get_collections()

# Filter images to those that have a DOI
collections = collections[collections.DOI.isnull()==False]

# Useless, but might as well save it
collections.to_csv("%s/collections_with_dois.tsv" %(results_directory),encoding="utf-8",sep="\t")


# Get image meta data for collections
images = api.get_images(collection_pks=collections.collection_id.tolist())

# load list of included image IDs (curated by Poldracklab) and exclude others
curated_images = pandas.read_csv('%s/included_images.csv' %(data_directory),header=None,names=['image_id'])
images = images.loc[images['image_id'].isin(curated_images['image_id'])]

## the following won't really have any effect, since the filtering
## is done by the explicit list above, but I'm leaving them
## to make it clear how the filtering was initially done
## however, if any of these criteria change in the neurovault
## database (modality, MNI, thresholded description, cognitive atlas task)
## this list could be filtered further

# Get rid of any not in MNI
images = images[images.not_mni == False]

# Get rid of thresholded images
images = images[images.is_thresholded == False]

# Remove single subject maps
images = images[images.analysis_level!='single-subject']
images = images[images.number_of_subjects!=1]

# Remove non fmri-BOLD
images = images[images.modality=='fMRI-BOLD']

# We can't use Rest or other/none
images = images[images.cognitive_paradigm_cogatlas_id.isnull()==False]
images = images[images.cognitive_paradigm_cogatlas.isin(["None / Other","rest eyes closed","rest eyes open"])==False]

# Limit to Z and T maps (all are Z and T)
z = images[images.map_type == "Z map"]
t = images[images.map_type == "T map"]

# Remove tmaps that do not have # subjects defined
t = t[t.number_of_subjects.isnull()==False]
images = z.append(t)

# Download images
standard = os.path.abspath("%s/mr/MNI152_T1_2mm_brain.nii.gz" %(here))
api.download_images(dest_dir=data_directory,images_df=images,target=standard)

# For T images, convert to Z. NeuroVault outputs two folders - original and resampled
resampled_dir = "%s/resampled" %(data_directory)

# We need to select a subset of the images, just the T Maps from the set
tmaps = [ "%s/%06d.nii.gz" %(resampled_dir,x) for x in t.image_id.tolist()]

# We need degrees of freedom to convert properly to Zstat maps.
dofs = []
for row in t.iterrows():
    dof = row[1].number_of_subjects -2
    dofs.append(dof)

# We will move converted Z maps, and as is Z maps, to a common folder
outfolder_z = "%s/resampled_z" %(data_directory)
make_dirs(outfolder_z)

for tt in range(0,len(tmaps)):
    tmap = tmaps[tt]
    dof = dofs[tt]
    zmap_new = "%s/%s" %(outfolder_z,os.path.split(tmap)[-1])
    if os.path.exists(zmap_new):
        continue
    if os.path.exists(tmap):
        TtoZ(tmap,output_nii=zmap_new,dof=dof)
    else:
        print('skipping due to missing tmap:%s'%tmap)

# Copy all (already) Z maps to the folder
zmaps = [ "%s/%06d.nii.gz" %(resampled_dir,x) for x in z.image_id.tolist()]
for zmap in zmaps:
    if not os.path.exists(zmap):
        print('skipping missing zmap: %s'%zmap)
        continue
    zmap_new = "%s/%s" %(outfolder_z,os.path.split(zmap)[-1])
    shutil.copyfile(zmap,zmap_new)

if len(glob("%s/*.nii.gz" %(outfolder_z))) != images.shape[0]:
    raise ValueError("ERROR: not all images were found in final folder %s" %(outfolder_z))

# We will actually need this one.
images.to_csv("%s/filtered_contrast_images.tsv" %(results_directory),encoding="utf-8",sep="\t")

# Give the user a warning if the number of images is different
if images.shape[0] != 93:
    print("Warning, the original analysis had 93 images, and this number has changed to %s." %(images.shape[0]))

# Finally, resample images to 4mm voxel for classification analysis
outfolder_z4mm = "%s/resampled_z_4mm" %(data_directory)
make_dirs(outfolder_z4mm)

maps = glob("%s/*.nii.gz" %(outfolder_z))
for mr in maps:
    image_name = os.path.basename(mr)
    print("Resampling %s to 4mm..." %(image_name))
    nii = nibabel.load(mr)
    nii_resamp = resample_img(nii,target_affine=numpy.diag([4,4,4]))
    nibabel.save(nii_resamp,"%s/%s" %(outfolder_z4mm,image_name))
# Out:
# BASE project directory is defined as -f
# Creating directory /home/mjfang/forward-modeling-cognitive-concepts/results
# Extracting NeuroVault collections meta data...
# http://neurovault.org/api/collections/?limit=100&format=json
# Found 921 results.
# Retrieving http://neurovault.org/api/collections/?format=json&limit=100&offset=100
# Retrieving http://neurovault.org/api/collections/?format=json&limit=100&offset=200
# Retrieving http://neurovault.org/api/collections/?format=json&limit=100&offset=300
# Retrieving http://neurovault.org/api/collections/?format=json&limit=100&offset=400
# Retrieving http://neurovault.org/api/collections/?format=json&limit=100&offset=500
# Retrieving http://neurovault.org/api/collections/?format=json&limit=100&offset=600
# Retrieving http://neurovault.org/api/collections/?format=json&limit=100&offset=700
# Retrieving http://neurovault.org/api/collections/?format=json&limit=100&offset=800
# Retrieving http://neurovault.org/api/collections/?format=json&limit=100&offset=900
# Extracting NeuroVault collections meta data...
# Retrieving collection 35...
# http://neurovault.org/api/collections/35/images/?format=json
# Retrieving collection 1054...
# http://neurovault.org/api/collections/1054/images/?format=json
# Retrieving collection 1345...
# http://neurovault.org/api/collections/1345/images/?format=json
# Retrieving collection 109...
# http://neurovault.org/api/collections/109/images/?format=json
# Retrieving collection 1194...
# http://neurovault.org/api/collections/1194/images/?format=json
# Retrieving collection 1056...
# http://neurovault.org/api/collections/1056/images/?format=json
# Retrieving collection 865...
# http://neurovault.org/api/collections/865/images/?format=json
# Retrieving collection 1039...
# http://neurovault.org/api/collections/1039/images/?format=json
# Retrieving collection 866...
# http://neurovault.org/api/collections/866/images/?format=json
# Retrieving collection 1195...
# http://neurovault.org/api/collections/1195/images/?format=json
# Retrieving collection 588...
# http://neurovault.org/api/collections/588/images/?format=json
# Retrieving collection 1057...
# http://neurovault.org/api/collections/1057/images/?format=json
# Retrieving collection 1196...
# http://neurovault.org/api/collections/1196/images/?format=json
# Retrieving collection 1288...
# http://neurovault.org/api/collections/1288/images/?format=json
# Retrieving collection 786...
# http://neurovault.org/api/collections/786/images/?format=json
# Retrieving collection 1197...
# http://neurovault.org/api/collections/1197/images/?format=json
# Retrieving collection 1058...
# http://neurovault.org/api/collections/1058/images/?format=json
# Retrieving collection 555...
# http://neurovault.org/api/collections/555/images/?format=json
# Retrieving collection 325...
# http://neurovault.org/api/collections/325/images/?format=json
# Retrieving collection 1059...
# http://neurovault.org/api/collections/1059/images/?format=json
# Retrieving collection 190...
# http://neurovault.org/api/collections/190/images/?format=json
# Retrieving collection 826...
# http://neurovault.org/api/collections/826/images/?format=json
# Retrieving collection 1322...
# http://neurovault.org/api/collections/1322/images/?format=json
# Retrieving collection 7...
# http://neurovault.org/api/collections/7/images/?format=json
# Retrieving collection 59...
# http://neurovault.org/api/collections/59/images/?format=json
# Retrieving collection 179...
# http://neurovault.org/api/collections/179/images/?format=json
# Retrieving collection 419...
# http://neurovault.org/api/collections/419/images/?format=json
# Retrieving collection 550...
# http://neurovault.org/api/collections/550/images/?format=json
# Retrieving collection 1060...
# http://neurovault.org/api/collections/1060/images/?format=json
# Retrieving collection 1061...
# http://neurovault.org/api/collections/1061/images/?format=json
# Retrieving collection 1939...
# http://neurovault.org/api/collections/1939/images/?format=json
# Retrieving collection 1062...
# http://neurovault.org/api/collections/1062/images/?format=json
# Retrieving collection 1324...
# http://neurovault.org/api/collections/1324/images/?format=json
# Retrieving collection 1035...
# http://neurovault.org/api/collections/1035/images/?format=json
# Retrieving collection 1276...
# http://neurovault.org/api/collections/1276/images/?format=json
# Retrieving collection 830...
# http://neurovault.org/api/collections/830/images/?format=json
# Retrieving collection 839...
# http://neurovault.org/api/collections/839/images/?format=json
# Retrieving collection 518...
# http://neurovault.org/api/collections/518/images/?format=json
# Retrieving collection 263...
# http://neurovault.org/api/collections/263/images/?format=json
# Retrieving collection 1325...
# http://neurovault.org/api/collections/1325/images/?format=json
# Retrieving collection 1683...
# http://neurovault.org/api/collections/1683/images/?format=json
# Found 378 results.
# Retrieving http://neurovault.org/api/collections/1683/images/?format=json&limit=100&offset=100
# Retrieving http://neurovault.org/api/collections/1683/images/?format=json&limit=100&offset=200
# Retrieving http://neurovault.org/api/collections/1683/images/?format=json&limit=100&offset=300
# Retrieving collection 1065...
# http://neurovault.org/api/collections/1065/images/?format=json
# Retrieving collection 844...
# http://neurovault.org/api/collections/844/images/?format=json
# Retrieving collection 837...
# http://neurovault.org/api/collections/837/images/?format=json
# Retrieving collection 831...
# http://neurovault.org/api/collections/831/images/?format=json
# Retrieving collection 77...
# http://neurovault.org/api/collections/77/images/?format=json
# Retrieving collection 13...
# http://neurovault.org/api/collections/13/images/?format=json
# Retrieving collection 838...
# http://neurovault.org/api/collections/838/images/?format=json
# Retrieving collection 45...
# http://neurovault.org/api/collections/45/images/?format=json
# Retrieving collection 1206...
# http://neurovault.org/api/collections/1206/images/?format=json
# Retrieving collection 857...
# http://neurovault.org/api/collections/857/images/?format=json
# Retrieving collection 40...
# http://neurovault.org/api/collections/40/images/?format=json
# Retrieving collection 1089...
# http://neurovault.org/api/collections/1089/images/?format=json
# Retrieving collection 1015...
# http://neurovault.org/api/collections/1015/images/?format=json
# Found 294 results.
# Retrieving http://neurovault.org/api/collections/1015/images/?format=json&limit=100&offset=100
# Retrieving http://neurovault.org/api/collections/1015/images/?format=json&limit=100&offset=200
# Retrieving collection 1055...
# http://neurovault.org/api/collections/1055/images/?format=json
# Retrieving collection 21...
# http://neurovault.org/api/collections/21/images/?format=json
# Retrieving collection 640...
# http://neurovault.org/api/collections/640/images/?format=json
# Retrieving collection 821...
# http://neurovault.org/api/collections/821/images/?format=json
# Retrieving collection 860...
# http://neurovault.org/api/collections/860/images/?format=json
# Retrieving collection 27...
# http://neurovault.org/api/collections/27/images/?format=json
# Retrieving collection 1268...
# http://neurovault.org/api/collections/1268/images/?format=json
# Retrieving collection 308...
# http://neurovault.org/api/collections/308/images/?format=json
# Retrieving collection 203...
# http://neurovault.org/api/collections/203/images/?format=json
# Retrieving collection 73...
# http://neurovault.org/api/collections/73/images/?format=json
# Retrieving collection 2...
# http://neurovault.org/api/collections/2/images/?format=json
# Retrieving collection 267...
# http://neurovault.org/api/collections/267/images/?format=json
# Retrieving collection 835...
# http://neurovault.org/api/collections/835/images/?format=json
# Retrieving collection 917...
# http://neurovault.org/api/collections/917/images/?format=json
# Retrieving collection 1208...
# http://neurovault.org/api/collections/1208/images/?format=json
# Retrieving collection 63...
# http://neurovault.org/api/collections/63/images/?format=json
# Retrieving collection 1359...
# http://neurovault.org/api/collections/1359/images/?format=json
# Retrieving collection 1051...
# http://neurovault.org/api/collections/1051/images/?format=json
# Retrieving collection 1030...
# http://neurovault.org/api/collections/1030/images/?format=json
# Retrieving collection 648...
# http://neurovault.org/api/collections/648/images/?format=json
# Retrieving collection 135...
# http://neurovault.org/api/collections/135/images/?format=json
# Retrieving collection 823...
# http://neurovault.org/api/collections/823/images/?format=json
# Retrieving collection 841...
# http://neurovault.org/api/collections/841/images/?format=json
# Retrieving collection 1104...
# http://neurovault.org/api/collections/1104/images/?format=json
# Retrieving collection 973...
# http://neurovault.org/api/collections/973/images/?format=json
# Retrieving collection 608...
# http://neurovault.org/api/collections/608/images/?format=json
# Retrieving collection 819...
# http://neurovault.org/api/collections/819/images/?format=json
# Retrieving collection 1424...
# http://neurovault.org/api/collections/1424/images/?format=json
# Retrieving collection 1467...
# http://neurovault.org/api/collections/1467/images/?format=json
# Retrieving collection 207...
# http://neurovault.org/api/collections/207/images/?format=json
# Retrieving collection 840...
# http://neurovault.org/api/collections/840/images/?format=json
# Retrieving collection 724...
# http://neurovault.org/api/collections/724/images/?format=json
# Retrieving collection 1326...
# http://neurovault.org/api/collections/1326/images/?format=json
# Retrieving collection 1597...
# http://neurovault.org/api/collections/1597/images/?format=json
# Retrieving collection 833...
# http://neurovault.org/api/collections/833/images/?format=json
# Retrieving collection 417...
# http://neurovault.org/api/collections/417/images/?format=json
# Retrieving collection 56...
# http://neurovault.org/api/collections/56/images/?format=json
# Retrieving collection 422...
# http://neurovault.org/api/collections/422/images/?format=json
# Retrieving collection 421...
# http://neurovault.org/api/collections/421/images/?format=json
# Retrieving collection 42...
# http://neurovault.org/api/collections/42/images/?format=json
# Retrieving collection 110...
# http://neurovault.org/api/collections/110/images/?format=json
# Retrieving collection 439...
# http://neurovault.org/api/collections/439/images/?format=json
# Retrieving collection 954...
# http://neurovault.org/api/collections/954/images/?format=json
# Retrieving collection 423...
# http://neurovault.org/api/collections/423/images/?format=json
# Retrieving collection 1470...
# http://neurovault.org/api/collections/1470/images/?format=json
# Retrieving collection 2043...
# http://neurovault.org/api/collections/2043/images/?format=json
# Retrieving collection 1880...
# http://neurovault.org/api/collections/1880/images/?format=json
# Retrieving collection 34...
# http://neurovault.org/api/collections/34/images/?format=json
# Retrieving collection 654...
# http://neurovault.org/api/collections/654/images/?format=json
# Retrieving collection 695...
# http://neurovault.org/api/collections/695/images/?format=json
# Retrieving collection 1942...
# http://neurovault.org/api/collections/1942/images/?format=json
# Retrieving collection 1191...
# http://neurovault.org/api/collections/1191/images/?format=json
# Retrieving collection 307...
# http://neurovault.org/api/collections/307/images/?format=json
# Retrieving collection 694...
# http://neurovault.org/api/collections/694/images/?format=json
# Retrieving collection 428...
# http://neurovault.org/api/collections/428/images/?format=json
# Retrieving collection 415...
# http://neurovault.org/api/collections/415/images/?format=json
# Retrieving collection 723...
# http://neurovault.org/api/collections/723/images/?format=json
# Retrieving collection 1088...
# http://neurovault.org/api/collections/1088/images/?format=json
# Retrieving collection 3...
# http://neurovault.org/api/collections/3/images/?format=json
# Retrieving collection 145...
# http://neurovault.org/api/collections/145/images/?format=json
# Retrieving collection 14...
# http://neurovault.org/api/collections/14/images/?format=json
# Retrieving collection 169...
# http://neurovault.org/api/collections/169/images/?format=json
# Retrieving collection 843...
# http://neurovault.org/api/collections/843/images/?format=json
# Retrieving collection 425...
# http://neurovault.org/api/collections/425/images/?format=json
# Retrieving collection 1072...
# http://neurovault.org/api/collections/1072/images/?format=json
# Retrieving collection 291...
# http://neurovault.org/api/collections/291/images/?format=json
# Retrieving collection 1151...
# http://neurovault.org/api/collections/1151/images/?format=json
# Retrieving collection 298...
# http://neurovault.org/api/collections/298/images/?format=json
# Retrieving collection 457...
# http://neurovault.org/api/collections/457/images/?format=json
# Retrieving collection 1073...
# http://neurovault.org/api/collections/1073/images/?format=json
# Retrieving collection 268...
# http://neurovault.org/api/collections/268/images/?format=json
# Retrieving collection 437...
# http://neurovault.org/api/collections/437/images/?format=json
# Retrieving collection 1126...
# http://neurovault.org/api/collections/1126/images/?format=json
# Retrieving collection 571...
# http://neurovault.org/api/collections/571/images/?format=json
# Retrieving collection 693...
# http://neurovault.org/api/collections/693/images/?format=json
# Retrieving collection 18...
# http://neurovault.org/api/collections/18/images/?format=json
# Retrieving collection 297...
# http://neurovault.org/api/collections/297/images/?format=json
# Retrieving collection 1446...
# http://neurovault.org/api/collections/1446/images/?format=json
# Retrieving collection 822...
# http://neurovault.org/api/collections/822/images/?format=json
# Retrieving collection 85...
# http://neurovault.org/api/collections/85/images/?format=json
# Retrieving collection 1029...
# http://neurovault.org/api/collections/1029/images/?format=json
# Retrieving collection 1212...
# http://neurovault.org/api/collections/1212/images/?format=json
# Retrieving collection 1447...
# http://neurovault.org/api/collections/1447/images/?format=json
# Retrieving collection 828...
# http://neurovault.org/api/collections/828/images/?format=json
# Retrieving collection 827...
# http://neurovault.org/api/collections/827/images/?format=json
# Retrieving collection 824...
# http://neurovault.org/api/collections/824/images/?format=json
# Retrieving collection 46...
# http://neurovault.org/api/collections/46/images/?format=json
# Retrieving collection 807...
# http://neurovault.org/api/collections/807/images/?format=json
# Retrieving collection 321...
# http://neurovault.org/api/collections/321/images/?format=json
# Retrieving collection 1351...
# http://neurovault.org/api/collections/1351/images/?format=json
# Retrieving collection 1186...
# http://neurovault.org/api/collections/1186/images/?format=json
# Retrieving collection 39...
# http://neurovault.org/api/collections/39/images/?format=json
# Retrieving collection 507...
# http://neurovault.org/api/collections/507/images/?format=json
# Retrieving collection 1003...
# http://neurovault.org/api/collections/1003/images/?format=json
# Retrieving collection 16...
# http://neurovault.org/api/collections/16/images/?format=json
# Retrieving collection 44...
# http://neurovault.org/api/collections/44/images/?format=json
# Retrieving collection 17...
# http://neurovault.org/api/collections/17/images/?format=json
# Retrieving collection 1080...
# http://neurovault.org/api/collections/1080/images/?format=json
# Retrieving collection 206...
# http://neurovault.org/api/collections/206/images/?format=json
# Retrieving collection 101...
# http://neurovault.org/api/collections/101/images/?format=json
# Retrieving collection 426...
# http://neurovault.org/api/collections/426/images/?format=json
# Retrieving collection 1158...
# http://neurovault.org/api/collections/1158/images/?format=json
# Retrieving collection 43...
# http://neurovault.org/api/collections/43/images/?format=json
# Retrieving collection 961...
# http://neurovault.org/api/collections/961/images/?format=json
# Retrieving collection 1255...
# http://neurovault.org/api/collections/1255/images/?format=json
# Retrieving collection 431...
# http://neurovault.org/api/collections/431/images/?format=json
# Retrieving collection 656...
# http://neurovault.org/api/collections/656/images/?format=json
# Retrieving collection 104...
# http://neurovault.org/api/collections/104/images/?format=json
# Retrieving collection 657...
# http://neurovault.org/api/collections/657/images/?format=json
# Retrieving collection 25...
# http://neurovault.org/api/collections/25/images/?format=json
# Retrieving collection 1238...
# http://neurovault.org/api/collections/1238/images/?format=json
# Retrieving collection 953...
# http://neurovault.org/api/collections/953/images/?format=json
# Retrieving collection 1083...
# http://neurovault.org/api/collections/1083/images/?format=json
# Retrieving collection 832...
# http://neurovault.org/api/collections/832/images/?format=json
# Retrieving collection 834...
# http://neurovault.org/api/collections/834/images/?format=json
# Retrieving collection 33...
# http://neurovault.org/api/collections/33/images/?format=json
# Retrieving collection 842...
# http://neurovault.org/api/collections/842/images/?format=json
# Retrieving collection 820...
# http://neurovault.org/api/collections/820/images/?format=json
# Retrieving collection 1037...
# http://neurovault.org/api/collections/1037/images/?format=json
# Retrieving collection 1280...
# http://neurovault.org/api/collections/1280/images/?format=json
# Retrieving collection 659...
# http://neurovault.org/api/collections/659/images/?format=json
# Retrieving collection 315...
# http://neurovault.org/api/collections/315/images/?format=json
# Retrieving collection 57...
# http://neurovault.org/api/collections/57/images/?format=json
# Retrieving collection 744...
# http://neurovault.org/api/collections/744/images/?format=json
# Retrieving collection 655...
# http://neurovault.org/api/collections/655/images/?format=json
# Retrieving collection 474...
# http://neurovault.org/api/collections/474/images/?format=json
# Retrieving collection 122...
# http://neurovault.org/api/collections/122/images/?format=json
# Retrieving collection 1244...
# http://neurovault.org/api/collections/1244/images/?format=json
# Retrieving collection 540...
# http://neurovault.org/api/collections/540/images/?format=json
# Retrieving collection 754...
# http://neurovault.org/api/collections/754/images/?format=json
# Retrieving collection 94...
# http://neurovault.org/api/collections/94/images/?format=json
# Retrieving collection 845...
# http://neurovault.org/api/collections/845/images/?format=json
# Retrieving collection 825...
# http://neurovault.org/api/collections/825/images/?format=json
# Retrieving collection 836...
# http://neurovault.org/api/collections/836/images/?format=json
# Retrieving collection 446...
# http://neurovault.org/api/collections/446/images/?format=json
# Retrieving collection 1323...
# http://neurovault.org/api/collections/1323/images/?format=json
# Retrieving collection 418...
# http://neurovault.org/api/collections/418/images/?format=json
# Retrieving collection 1486...
# http://neurovault.org/api/collections/1486/images/?format=json
# Retrieving collection 599...
# http://neurovault.org/api/collections/599/images/?format=json
# Retrieving collection 1377...
# http://neurovault.org/api/collections/1377/images/?format=json
# Retrieving collection 1070...
# http://neurovault.org/api/collections/1070/images/?format=json
# Retrieving collection 1649...
# http://neurovault.org/api/collections/1649/images/?format=json
# Retrieving collection 1378...
# http://neurovault.org/api/collections/1378/images/?format=json
# Retrieving collection 1408...
# http://neurovault.org/api/collections/1408/images/?format=json
# Retrieving collection 1406...
# http://neurovault.org/api/collections/1406/images/?format=json
# Retrieving collection 1387...
# http://neurovault.org/api/collections/1387/images/?format=json
# Retrieving collection 1904...
# http://neurovault.org/api/collections/1904/images/?format=json
# Retrieving collection 1379...
# http://neurovault.org/api/collections/1379/images/?format=json
# Retrieving collection 1625...
# http://neurovault.org/api/collections/1625/images/?format=json
# Retrieving collection 1478...
# http://neurovault.org/api/collections/1478/images/?format=json
# Retrieving collection 1546...
# http://neurovault.org/api/collections/1546/images/?format=json
# Retrieving collection 1370...
# http://neurovault.org/api/collections/1370/images/?format=json
# Retrieving collection 1944...
# http://neurovault.org/api/collections/1944/images/?format=json
# Retrieving collection 1598...
# http://neurovault.org/api/collections/1598/images/?format=json
# Retrieving collection 904...
# http://neurovault.org/api/collections/904/images/?format=json
# Retrieving collection 1848...
# http://neurovault.org/api/collections/1848/images/?format=json
# Retrieving collection 1508...
# http://neurovault.org/api/collections/1508/images/?format=json
# Retrieving collection 503...
# http://neurovault.org/api/collections/503/images/?format=json
# Found 5067 results.
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=100
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=200
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=300
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=400
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=500
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=600
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=700
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=800
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=900
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=1000
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=1100
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=1200
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=1300
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=1400
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=1500
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=1600
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=1700
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=1800
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=1900
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=2000
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=2100
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=2200
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=2300
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=2400
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=2500
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=2600
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=2700
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=2800
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=2900
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=3000
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=3100
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=3200
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=3300
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=3400
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=3500
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=3600
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=3700
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=3800
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=3900
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=4000
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=4100
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=4200
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=4300
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=4400
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=4500
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=4600
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=4700
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=4800
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=4900
# Retrieving http://neurovault.org/api/collections/503/images/?format=json&limit=100&offset=5000
# Retrieving collection 1066...
# http://neurovault.org/api/collections/1066/images/?format=json
# Retrieving collection 1385...
# http://neurovault.org/api/collections/1385/images/?format=json
# Retrieving collection 1941...
# http://neurovault.org/api/collections/1941/images/?format=json
# Retrieving collection 1551...
# http://neurovault.org/api/collections/1551/images/?format=json
# Retrieving collection 1858...
# http://neurovault.org/api/collections/1858/images/?format=json
# Retrieving collection 1929...
# http://neurovault.org/api/collections/1929/images/?format=json
# Retrieving collection 1998...
# http://neurovault.org/api/collections/1998/images/?format=json
# Retrieving collection 1846...
# http://neurovault.org/api/collections/1846/images/?format=json
# Retrieving collection 1265...
# http://neurovault.org/api/collections/1265/images/?format=json
# Retrieving collection 1503...
# http://neurovault.org/api/collections/1503/images/?format=json
# Retrieving collection 1458...
# http://neurovault.org/api/collections/1458/images/?format=json
# Retrieving collection 1634...
# http://neurovault.org/api/collections/1634/images/?format=json
# Retrieving collection 1949...
# http://neurovault.org/api/collections/1949/images/?format=json
# Retrieving collection 858...
# http://neurovault.org/api/collections/858/images/?format=json
# Retrieving collection 1636...
# http://neurovault.org/api/collections/1636/images/?format=json
# Retrieving collection 1970...
# http://neurovault.org/api/collections/1970/images/?format=json
# Retrieving collection 1917...
# http://neurovault.org/api/collections/1917/images/?format=json
# Retrieving collection 1637...
# http://neurovault.org/api/collections/1637/images/?format=json
# Retrieving collection 1865...
# http://neurovault.org/api/collections/1865/images/?format=json
# Retrieving collection 2070...
# http://neurovault.org/api/collections/2070/images/?format=json
# Retrieving collection 1662...
# http://neurovault.org/api/collections/1662/images/?format=json
# Retrieving collection 2017...
# http://neurovault.org/api/collections/2017/images/?format=json
# Retrieving collection 160...
# http://neurovault.org/api/collections/160/images/?format=json
# Retrieving collection 445...
# http://neurovault.org/api/collections/445/images/?format=json
# Retrieving collection 394...
# http://neurovault.org/api/collections/394/images/?format=json
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0111.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0111.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0111.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3129.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3129.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3129.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3131.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3131.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3131.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3142.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3142.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3142.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3154.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3154.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3154.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3156.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3156.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3156.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3158.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3158.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3158.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3160.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3160.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3160.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3162.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3162.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3162.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3164.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3164.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3164.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3173.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3173.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3173.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3175.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3175.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3175.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3179.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3179.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3179.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3180.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3180.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3180.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3185.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3185.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3185.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3186.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3186.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3186.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3187.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3187.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3187.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3188.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3188.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3188.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3191.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3191.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3191.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3192.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3192.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3192.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3193.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3193.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3193.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3194.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3194.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3194.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/2963.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/2963.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/2963.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/8625.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/8625.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/8625.nii.gz
# /home/mjfang/anaconda2/lib/python2.7/site-packages/scipy/ndimage/interpolation.py:430: UserWarning: The behaviour of affine_transform with a one-dimensional array supplied for the matrix parameter has changed in scipy 0.18.0.
#   "The behaviour of affine_transform with a one-dimensional "
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0177.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0177.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0177.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0178.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0178.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0178.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0183.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0183.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0183.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0135.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0135.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0135.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0136.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0136.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0136.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0138.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0138.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0138.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0139.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0139.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0139.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0140.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0140.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0140.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0141.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0141.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0141.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/2718.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/2718.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/2718.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/2723.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/2723.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/2723.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/2729.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/2729.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/2729.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/2731.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/2731.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/2731.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0142.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0142.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0142.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0143.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0143.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0143.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0144.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0144.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0144.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0146.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0146.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0146.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0147.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0147.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0147.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0149.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0149.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0149.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0154.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0154.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0154.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3039.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3039.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3039.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3040.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3040.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3040.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/3041.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/3041.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/3041.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/2824.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/2824.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/2824.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/2826.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/2826.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/2826.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0109.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0109.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0109.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/1750.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/1750.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/1750.nii.gz
# /home/mjfang/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.py:3569: RuntimeWarning: Invalid value encountered in median
#   RuntimeWarning)
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/2714.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/2714.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/2714.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/10924.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/10924.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/10924.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0003.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0003.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0003.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0004.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0004.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0004.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/8718.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/8718.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/8718.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/8719.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/8719.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/8719.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/2863.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/2863.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/2863.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/2866.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/2866.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/2866.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/8727.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/8727.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/8727.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/8730.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/8730.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/8730.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/8820.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/8820.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/8820.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/1583.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/1583.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/1583.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/1584.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/1584.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/1584.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/1585.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/1585.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/1585.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/1586.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/1586.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/1586.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/1587.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/1587.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/1587.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0186.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0186.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0186.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0187.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0187.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0187.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0188.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0188.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0188.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0190.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0190.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0190.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0116.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0116.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0116.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0118.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0118.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0118.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0119.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0119.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0119.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0120.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0120.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0120.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0122.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0122.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0122.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0172.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0172.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0172.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0173.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0173.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0173.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/2883.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/2883.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/2883.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0157.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0157.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0157.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0159.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0159.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0159.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0164.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0164.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0164.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0165.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0165.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0165.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0166.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0166.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0166.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0394.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0394.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0394.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0395.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0395.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0395.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0401.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0401.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0401.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0407.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0407.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0407.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0412.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0412.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0412.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0415.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0415.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0415.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0418.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0418.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0418.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0419.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0419.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0419.nii.gz
# Downloading /home/mjfang/forward-modeling-cognitive-concepts/data/original/0420.nii.gz
# Extrapolating /home/mjfang/forward-modeling-cognitive-concepts/data/original/0420.nii.gz
# Resampling /home/mjfang/forward-modeling-cognitive-concepts/data/original/0420.nii.gz
# Creating directory /home/mjfang/forward-modeling-cognitive-concepts/data/resampled_z
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/008625.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000177.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000178.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000183.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000135.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000136.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000138.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000139.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000140.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000141.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/002718.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/002723.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/002729.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/002731.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000142.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000143.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000144.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000146.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000147.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000149.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000154.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/003039.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/003040.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/003041.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/002824.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/002826.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000109.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/001750.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/002714.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/010924.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000003.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000004.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/008718.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/008719.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/002863.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/002866.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/008727.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/008730.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/008820.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/001583.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/001584.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/001585.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/001586.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/001587.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000186.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000187.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000188.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000190.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000116.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000118.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000119.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000120.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000122.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000172.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000173.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/002883.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000157.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000159.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000164.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000165.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000166.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000394.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000395.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000401.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000407.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000412.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000415.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000418.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000419.nii.gz to Z-Scores...
# Converting map /home/mjfang/forward-modeling-cognitive-concepts/data/resampled/000420.nii.gz to Z-Scores...
# Creating directory /home/mjfang/forward-modeling-cognitive-concepts/data/resampled_z_4mm
# Resampling 008625.nii.gz to 4mm...
# Resampling 003173.nii.gz to 4mm...
# Resampling 003180.nii.gz to 4mm...
# Resampling 000412.nii.gz to 4mm...
# Resampling 003039.nii.gz to 4mm...
# Resampling 000141.nii.gz to 4mm...
# Resampling 000183.nii.gz to 4mm...
# Resampling 001583.nii.gz to 4mm...
# Resampling 000395.nii.gz to 4mm...
# Resampling 003160.nii.gz to 4mm...
# Resampling 000135.nii.gz to 4mm...
# Resampling 000420.nii.gz to 4mm...
# Resampling 002718.nii.gz to 4mm...
# Resampling 008718.nii.gz to 4mm...
# Resampling 002731.nii.gz to 4mm...
# Resampling 000003.nii.gz to 4mm...
# Resampling 001584.nii.gz to 4mm...
# Resampling 000142.nii.gz to 4mm...
# Resampling 003175.nii.gz to 4mm...
# Resampling 003192.nii.gz to 4mm...
# Resampling 003188.nii.gz to 4mm...
# Resampling 000144.nii.gz to 4mm...
# Resampling 010924.nii.gz to 4mm...
# Resampling 000418.nii.gz to 4mm...
# Resampling 000164.nii.gz to 4mm...
# Resampling 003185.nii.gz to 4mm...
# Resampling 002863.nii.gz to 4mm...
# Resampling 008820.nii.gz to 4mm...
# Resampling 002883.nii.gz to 4mm...
# Resampling 000118.nii.gz to 4mm...
# Resampling 002866.nii.gz to 4mm...
# Resampling 002729.nii.gz to 4mm...
# Resampling 003187.nii.gz to 4mm...
# Resampling 000111.nii.gz to 4mm...
# Resampling 000004.nii.gz to 4mm...
# Resampling 003164.nii.gz to 4mm...
# Resampling 002824.nii.gz to 4mm...
# Resampling 002826.nii.gz to 4mm...
# Resampling 000401.nii.gz to 4mm...
# Resampling 008719.nii.gz to 4mm...
# Resampling 003156.nii.gz to 4mm...
# Resampling 003158.nii.gz to 4mm...
# Resampling 000177.nii.gz to 4mm...
# Resampling 000407.nii.gz to 4mm...
# Resampling 003186.nii.gz to 4mm...
# Resampling 000190.nii.gz to 4mm...
# Resampling 003191.nii.gz to 4mm...
# Resampling 001586.nii.gz to 4mm...
# Resampling 003142.nii.gz to 4mm...
# Resampling 000166.nii.gz to 4mm...
# Resampling 003040.nii.gz to 4mm...
# Resampling 000154.nii.gz to 4mm...
# Resampling 000165.nii.gz to 4mm...
# Resampling 003162.nii.gz to 4mm...
# Resampling 001585.nii.gz to 4mm...
# Resampling 003129.nii.gz to 4mm...
# Resampling 000394.nii.gz to 4mm...
# Resampling 000109.nii.gz to 4mm...
# Resampling 000187.nii.gz to 4mm...
# Resampling 000188.nii.gz to 4mm...
# Resampling 000138.nii.gz to 4mm...
# Resampling 002714.nii.gz to 4mm...
# Resampling 002723.nii.gz to 4mm...
# Resampling 000186.nii.gz to 4mm...
# Resampling 008727.nii.gz to 4mm...
# Resampling 003179.nii.gz to 4mm...
# Resampling 000173.nii.gz to 4mm...
# Resampling 000119.nii.gz to 4mm...
# Resampling 000139.nii.gz to 4mm...
# Resampling 003041.nii.gz to 4mm...
# Resampling 003193.nii.gz to 4mm...
# Resampling 000159.nii.gz to 4mm...
# Resampling 002963.nii.gz to 4mm...
# Resampling 000116.nii.gz to 4mm...
# Resampling 003131.nii.gz to 4mm...
# Resampling 001750.nii.gz to 4mm...
# Resampling 008730.nii.gz to 4mm...
# Resampling 000147.nii.gz to 4mm...
# Resampling 000149.nii.gz to 4mm...
# Resampling 000415.nii.gz to 4mm...
# Resampling 000157.nii.gz to 4mm...
# Resampling 000419.nii.gz to 4mm...
# Resampling 001587.nii.gz to 4mm...
# Resampling 000178.nii.gz to 4mm...
# Resampling 000143.nii.gz to 4mm...
# Resampling 000172.nii.gz to 4mm...
# Resampling 000140.nii.gz to 4mm...
# Resampling 000120.nii.gz to 4mm...
# Resampling 000146.nii.gz to 4mm...
# Resampling 000122.nii.gz to 4mm...
# Resampling 003194.nii.gz to 4mm...
# Resampling 003154.nii.gz to 4mm...
# Resampling 000136.nii.gz to 4mm...

# %%
"""
second step in forward modeling analysis - generating data structures to look up associated Cognitive Atlas terms
    with the images downloaded in 0.neurovault_images.py

"""

from cognitiveatlas.api import get_concept

from glob import glob

import numpy
import os
import pandas
import pickle
import re
import sys

from utils import (
   get_base, get_pwd, make_dirs
)


# Get the base and present working directory
base = get_base()
here = get_pwd()

data = os.path.abspath("%s/data" %(here))
results = os.path.abspath("%s/results" %(here))

# Read in images metadata
images = pandas.read_csv("%s/filtered_contrast_images.tsv" %results,sep="\t",index_col=0)

unique_concepts = dict()
for row in images.iterrows():
    idx = row[1].image_id
    # There is a bug with getting contrasts for these two images - these I manually looked up (@vsoch):
    if idx == 109:
        unique_concepts[idx] = ["trm_567982752ff4a","trm_4a3fd79d0afcf","trm_5534111a8bc96",
                                "trm_557b48a224b95","trm_557b4a81a4a17","trm_4a3fd79d0b64e","trm_4a3fd79d0a33b",
                                "trm_557b4a7315f1b","trm_4a3fd79d0af71","trm_557b4b56de455","trm_557b4add1837e"]
    elif idx == 118:
        unique_concepts[idx] = ["trm_4a3fd79d0b642","trm_4a3fd79d0a33b","trm_557b4a7315f1b","trm_4a3fd79d0af71",
                                "trm_557b4b56de455"]
    else:
        contrast = row[1].cognitive_contrast_cogatlas_id
        concepts = get_concept(contrast_id=contrast)
        concepts = numpy.unique(concepts.pandas.id).tolist() 
        unique_concepts[idx] = concepts
    
all_concepts = []
for image_id,concepts in unique_concepts.items():
    for concept in concepts:
        if concept not in all_concepts:
            all_concepts.append(concept)


res = {"all_concepts":all_concepts,"unique_concepts":unique_concepts,"images":images}

## STEP 1: GENERATE IMAGE BY CONCEPT DATA FRAME
concept_df = pandas.DataFrame(0,columns=all_concepts,index=images.image_id.unique().tolist())
for image_id,concepts in unique_concepts.items():
    concept_df.loc[image_id,concepts] = 1   

res["concept_df"] = concept_df
pickle.dump(res,open("%s/concepts.pkl" %results,"wb"))
concept_df.to_csv("%s/concepts_binary_df.tsv" %results,sep="\t")

## STEP 2: Generate image lookup
image_folder = "%s/resampled_z_4mm" %(data)
files = glob("%s/*.nii.gz" %image_folder)

if len(files) == 0:
    print(("Error, did not find image files in %s. Did you generate them with 0.neurovault_images.py?" %(image_folder)))
else:
    lookup = dict()
    for f in files:
        image_id = int(os.path.basename(f).strip(".nii.gz"))
        if image_id in concept_df.index:
            lookup[image_id] = f
        else:
            print(("Cannot find image %s in concept data frame" %(image_id)))

    pickle.dump(lookup,open("%s/image_nii_lookup.pkl" %results,"wb"))
# Out:
# BASE project directory is defined as -f
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553e7a5b2584d
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_5531474e117df
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55314757a78a1
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55314a1a5514c
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55315226076d3
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55315270d1e14
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55315278ea6cc
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_5531528173117
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_5531528989cc7
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553152908ac51
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553149868c670
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553149979dc2e
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553147b362347
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55314940f18c6
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55314b2a72bee
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55314b49e5c9d
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55314b56bceed
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55314b5e393d2
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55314aff55913
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55314b0643005
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55314b12878f7
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55314b1edb310
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553fc50126261
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55ef43b5be6da
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a694a86e65
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_5358f019cdf06
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4decfedb91973
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4ebca72d737c1
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399e161c884
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399dc274d97
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_54f8cbcb6fab6
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4ebcaad4c41d7
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4cacf26718047
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a7710d845a
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a7683a550a
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a768dc270f
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a7740160a3
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4ebca202935c6
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4b44a4d544ee7
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399a202b4ff
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399d6bcd8dc
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4c6b5fd5bfc41
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399a3f5e512
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4ebca22149619
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553999f2c69ef
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399a008d960
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4ebca1f15eb7d
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_5181f83b8eaae
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_5181f863d5591
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a6e9a84bd2
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a73a084bdd
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55ef440b3f6f2
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55ef1305643e9
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_5181f79e38fb2
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_5175b81f53bf3
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4cacee8ad4b14
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a6e7daf8e6
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a6ed942692
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_5679bec3715cd
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a6e9a84bd2
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553149bc9f9d1
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55410975ce70b
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_5541098145b5a
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55410992b9c4b
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_554109af50e85
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_554109c5544c8
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399e3b3d13e
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399e44106d4
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399e5388e65
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399e5ab094d
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399fa95aaee
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399f9ac9c55
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399f7c60721
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_55399f8675b23
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a682f464e7
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a68284e225
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553a689b663ed
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4ebcaa52e7dbd
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4ebca9e1d3a16
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_54f8cb27bce65
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4ebcaa755a7e5
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_4ebcaa463d20e
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553e85d4af020
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553e8672a9f1d
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553e86042df77
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553e85fc78496
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553e865d69738
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553e860cb6e0a
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553e8616191c4
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553e865074ad4
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>
# http://cognitiveatlas.org/api/v-alpha/concept?contrast_id=cnt_553e85f11747b
# Result Includes:<pandas:data frame><json:dict><txt:str><url:str>

# %%
"""
permutation (third) step in forward modeling analysis - building a forward model, testing with 2 images held out. This is the submission script to run the analysis, submitting to a SLURM cluster. You MUST edit the last line of this script for your particular submission command. If you do not use this kind of cluster, you should edit the end of the script (where submission occurs) to fit your format.

  Classification framework
  for image1 in all images:
     for image2 in allimages:
         if image1 != image2:
             hold out image 1 and image 2, generate regression parameter matrix using other images
             generate predicted image for image 1 [PR1]
             generate predicted image for image 2 [PR2]
             classify image 1 as fitting best to PR1 or PR2
             classify image 2 as fitting best to PR1 or PR2
"""

import os
import pandas
import sys

from utils import (
   get_base, get_pwd, make_dirs
)

# VARIABLES FOR SLURM
max_runtime="2-00:00"                    # Two days. Each script needs ~10-15 minutes, 30 is recommended for buffer
memory="32000"                           # 16000 might also work
submission_command="sbatch"                  # Your cluster submission command, eg sbatch, qsub
submission_args="-p russpold --qos russpold" # Does not need spaces to left and right


# Get the base and present working directory
base = get_base()
here = get_pwd()

data = os.path.abspath("%s/data" %(base))
results = os.path.abspath("%s/results" %(base))
output_folder = "%s/permutations" %results  

# Make the output directory
make_dirs(output_folder,reason="for permutation results.")

# Images by Concepts data frame
labels_tsv = "%s/concepts_binary_df.tsv" %results
images = pandas.read_csv(labels_tsv,sep="\t",index_col=0)
image_lookup = "%s/image_nii_lookup.pkl" %results

# We will need these folders to exist for job and output files
log_folders = ["%s/.out" %here,"%s/.job" %here]
make_dirs(log_folders)    

# Image metadata with number of subjects included
contrast_file = "%s/filtered_contrast_images.tsv" %results

for image1_holdout in images.index.tolist():
    print "Parsing %s" %(image1_holdout)
    for image2_holdout in images.index.tolist():
        if (image1_holdout != image2_holdout) and (image1_holdout < image2_holdout):
            output_file = "%s/%s_%s_perform.pkl" %(output_folder,image1_holdout,image2_holdout)
            if not os.path.exists(output_file):
                
                
                
#                 job_id = "%s_%s" %(image1_holdout,image2_holdout)
#                 filey = "%s/.job/class_%s.job" %(here,job_id)
#                 filey = open(filey,"w")
#                 filey.writelines("#!/bin/bash\n")
#                 filey.writelines("#SBATCH --job-name=%s\n" %(job_id))
#                 filey.writelines("#SBATCH --output=%s/.out/%s.out\n" %(here,job_id))
#                 filey.writelines("#SBATCH --error=%s/.out/%s.err\n" %(here,job_id))
#                 filey.writelines("#SBATCH --time=%s\n" %(max_runtime))
#                 filey.writelines("#SBATCH --mem=%s\n" %(memory))
#                 filey.writelines("python %s/2.encoding_regression_performance.py %s %s %s %s %s %s" %(here, 
#                                                                                                       image1_holdout, 
#                                                                                                       image2_holdout, 
#                                                                                                       output_file, 
#                                                                                                       labels_tsv, 
#                                                                                                       image_lookup, 
#                                                                                                       contrast_file))
#                 filey.close()
#                 os.system("%s %s " + "%s/.job/class_%s.job" %(submission_command,
#                                                               submission_args,
#                                                               here,
#                                                               job_id))
